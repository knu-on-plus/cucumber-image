# %%
import cv2
import sys, os
import numpy as np
import torch
from matplotlib import pyplot as plt
import pandas as pd
from collections import defaultdict

from sam2.build_sam import build_sam2
from sam2.sam2_image_predictor import SAM2ImagePredictor
#from segment_anything import SamPredictor, sam_model_registry
from typing import List, Tuple
from custom_utils import load_images_and_boxes, plot_masks_on_images, save_masks, resize_images_and_masks, show_mask, show_points, show_box, show_masks

# %%
if torch.cuda.is_available():
    device = torch.device("cuda")
elif torch.backends.mps.is_available():
    device = torch.device("mps")
else:
    device = torch.device("cpu")
print(f"using device: {device}")

if device.type == "cuda":
    # use bfloat16 for the entire notebook
    torch.autocast("cuda", dtype=torch.bfloat16).__enter__()
    # turn on tfloat32 for Ampere GPUs (https://pytorch.org/docs/stable/notes/cuda.html#tensorfloat-32-tf32-on-ampere-devices)
    if torch.cuda.get_device_properties(0).major >= 8:
        torch.backends.cuda.matmul.allow_tf32 = True
        torch.backends.cudnn.allow_tf32 = True
# Out:
# using device: cuda

# %%
# 이미지와 레이블 경로
image_folder = '/home/knuvi/Desktop/song/cucumber-image/data/oi/images'
label_folder = '/home/knuvi/Desktop/song/cucumber-image/yolo_detection/oi_leaves2/labels'
mask_output_folder = '/home/knuvi/Desktop/song/cucumber-image/data/oi_leaves/mask'  # 마스크를 저장할 폴더 경로

sam2_checkpoint = '/home/knuvi/Desktop/song/cucumber-image/segment-anything-2/sam2_hiera_large.pt'
model_cfg = "sam2_hiera_l.yaml"

# %%
sam2 = build_sam2(model_cfg, sam2_checkpoint, device=device)
mask_predictor = SAM2ImagePredictor(sam2)

# %%
def save_images_with_new_name(bboxes, image_path, image_index, new_image_dir):
    # 새로운 이미지 이름 생성 (레이블 수를 포함)
    label_count = len(bboxes)
    new_image_name = f"oi_{str(image_index).zfill(3)}_{label_count}.jpg"

    # 이미지 저장 경로
    new_image_path = os.path.join(new_image_dir, new_image_name)
    
    # 이미지를 새 경로에 저장
    image = cv2.imread(image_path)
    if image is not None:
        cv2.imwrite(new_image_path, image)
        print(f"이미지 저장됨: {new_image_path}")
        return new_image_name
    else:
        print(f"이미지를 로드할 수 없음: {image_path}")
        return None

def load_bboxes_from_txt(txt_file):
    bboxes = []
    class_labels = []  # 각 bbox의 클래스 정보 저장
    with open(txt_file, 'r') as f:
        lines = f.readlines()
        for line in lines:
            # txt 파일 형식: class x_min y_min x_max y_max
            class_id, x_min, y_min, x_max, y_max, _ = map(float, line.strip().split())
            if class_id == 0 or class_id == 1:  # class 0 (cucumber) 또는 class 1 (leaf)
                # SAM에 들어갈 bbox 형식: [x_min, y_min, x_max, y_max]
                bboxes.append([int(x_min), int(y_min), int(x_max), int(y_max)])
                class_labels.append(int(class_id))  # 클래스 정보를 저장
    return bboxes, class_labels
 
# 바운딩 박스를 저장하는 함수 (마스크 파일명과 동일하게 저장)
def save_bboxes_with_mask_name(bboxes, class_labels, mask_filename, label_dir):
    # 확장자 제거 (".png" 또는 다른 확장자를 제거)
    base_name = os.path.splitext(mask_filename)[0]
    label_filename = f"{base_name}.txt"
    label_full_path = os.path.join(label_dir, label_filename)
    
    # 바운딩 박스 정보를 텍스트 파일로 저장
    with open(label_full_path, 'w') as f:
        for bbox, class_id in zip(bboxes, class_labels):
            x_min, y_min, x_max, y_max = bbox
            # 저장 형식: class_id x_min y_min x_max y_max
            f.write(f"{class_id} {x_min} {y_min} {x_max} {y_max}\n")
    
    print(f"바운딩 박스 저장됨: {label_full_path}")

def generate_masks(image_path, bboxes, class_labels, score_threshold = 0.7):
    image = cv2.imread(image_path)
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    masks_list = []
    filtered_class_labels = []  # 조건을 만족하는 클래스 레이블 저장
    filtered_bboxes = []  # 조건을 만족하는 bbox 저장
    
    for i, bbox in enumerate(bboxes):
        x_min, y_min, x_max, y_max = bbox
        box = np.array([x_min, y_min, x_max, y_max])  # bbox 좌표 설정
        
        # bbox의 중앙 좌표 계산
        center_x = (x_min + x_max) // 2
        center_y = (y_min + y_max) // 2
        input_point = np.array([[center_x, center_y]])  # bbox 중앙 좌표
        input_label = np.array([class_labels[i]])  # class number (0: cucumber, 1: leaf)

        # SAM 모델을 통한 마스크 예측
        mask_predictor.set_image(image_rgb)
        masks, scores, logits = mask_predictor.predict(
            box=box,
            multimask_output=True,
            point_coords=input_point,
            point_labels=input_label
        )

        # 스코어가 가장 높은 마스크만 선택
        highest_score_idx = np.argmax(scores)
        highest_score = scores[highest_score_idx]
        best_mask = masks[highest_score_idx]  # 가장 높은 스코어의 마스크 선택
        if highest_score >= score_threshold:
            masks_list.append(best_mask)  # 조건을 만족하는 마스크 저장
            filtered_class_labels.append(class_labels[i])  # 해당 마스크의 클래스 레이블 저장
            filtered_bboxes.append(bbox)
            print(f"bbox {i + 1}: 가장 높은 score: {highest_score}로 저장됨")
        else:
            print(f"bbox {i + 1}: score {highest_score}로 저장되지 않음")
    
    return masks_list, filtered_class_labels, filtered_bboxes

# %%
def save_masks_with_new_name(masks, class_labels, bboxes, new_image_name, mask_dir, label_dir):
    # 확장자 제거 (".jpg" 또는 다른 확장자를 제거)
    base_name = os.path.splitext(new_image_name)[0]
    
    # 각 클래스 ID에 대해 파일명이 중복되지 않도록 번호 추가
    mask_counter = {}

    for idx, (mask, class_id, bbox) in enumerate(zip(masks, class_labels, bboxes)):
        # 해당 class_id에 대한 마스크 번호를 저장하고, 없으면 0으로 초기화
        if class_id not in mask_counter:
            mask_counter[class_id] = 0
        else:
            mask_counter[class_id] += 1

        # 마스크 파일명 생성 (중복 방지용 번호 포함)
        mask_number = str(mask_counter[class_id]).zfill(2)  # 두 자리 숫자로 포맷
        mask_filename = f"{base_name}_{class_id}_{mask_number}.png"
        mask_full_path = os.path.join(mask_dir, mask_filename)

        # 마스크 저장 (0과 255 값으로 이진화하여 저장)
        cv2.imwrite(mask_full_path, mask * 255)  # 이진화된 마스크를 PNG로 저장
        print(f"마스크 저장됨: {mask_full_path}")

        # 바운딩 박스 정보도 마스크 파일명과 동일하게 저장
        save_bboxes_with_mask_name([bbox], [class_id], mask_filename, label_dir)

def process_images_and_masks(image_paths, label_dir, new_image_path, mask_path, bbox_dir, start_index=1, score_threshold=0.5):
    image_index = start_index
    # 3개의 이미지에 대한 SAM 마스크 생성 및 시각화
    for image_path in image_paths:
        
        
        # 저장된 bbox 불러오기
        image_filename = os.path.basename(image_path)  # 이미지 파일 이름 추출
        txt_file = os.path.join(label_dir, os.path.splitext(image_filename)[0] + '.txt')  # 동일한 경로의 txt 파일
        if os.path.exists(txt_file):
            bboxes, class_labels = load_bboxes_from_txt(txt_file)
            if len(bboxes) == 0:
                print(f"레이블이 없는 이미지: {image_filename}")
                continue
        
        # 새로운 이름으로 이미지 저장
        new_image_name = save_images_with_new_name(bboxes, image_path, image_index, new_image_path)
        if new_image_name is None:
            continue

        # 유효한 bbox에 대해 SAM 마스크 생성
        if bboxes:
            masks, filtered_class_labels, filtered_bboxes = generate_masks(image_path, bboxes, class_labels, score_threshold=0.5)

            # 마스크, bbox 저장
            save_masks_with_new_name(masks, filtered_class_labels, filtered_bboxes, new_image_name, mask_path, bbox_dir)   
        else:
            print(f"No valid bboxes found for image {image_path}")

        image_index += 1

# %%
image_paths = [
    #'/home/knuvi/Desktop/song/cucumber-image/data/oi/images/V003_3_3_1_2_4_2_2_1_0_0_20221015_5068_20240422195045.jpg',
    '/home/knuvi/Desktop/song/cucumber-image/data/oi/images/V003_3_3_1_2_4_2_2_1_0_0_20221019_5096_20240422195046.jpg'
]

# bbox 정보가 저장된 경로 (YOLO 레이블이 있는 디렉토리)
label_dir = '/home/knuvi/Desktop/song/cucumber-image/yolo_detection/oi_leaves2/labels'
new_image_dir = '/home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images'
mask_dir = '/home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks'
bbox_dir = '/home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels'
image_dir = '/home/knuvi/Desktop/song/cucumber-image/data/oi/images'

image_paths = []
for image_file in os.listdir(image_dir):
    if image_file.endswith(('.jpg', '.jpeg', '.png')):  # 이미지 파일만 처리
        image_path = os.path.join(image_dir, image_file)
        image_paths.append(image_path)

process_images_and_masks(image_paths, label_dir, new_image_dir, mask_dir, bbox_dir, score_threshold=0.7)
# Out:
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_001_1.jpg
# bbox 1: 가장 높은 score: 0.98046875로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_001_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_001_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_002_1.jpg
# bbox 1: 가장 높은 score: 0.98046875로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_002_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_002_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_003_1.jpg
# bbox 1: 가장 높은 score: 0.98046875로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_003_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_003_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_004_1.jpg
# bbox 1: 가장 높은 score: 0.9765625로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_004_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_004_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_005_1.jpg
# bbox 1: 가장 높은 score: 0.98046875로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_005_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_005_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_006_3.jpg
# bbox 1: 가장 높은 score: 0.9765625로 저장됨
# bbox 2: 가장 높은 score: 0.9609375로 저장됨
# bbox 3: 가장 높은 score: 0.9921875로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_006_3_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_006_3_0_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_006_3_1_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_006_3_1_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_006_3_1_01.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_006_3_1_01.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_007_2.jpg
# bbox 1: 가장 높은 score: 0.97265625로 저장됨
# bbox 2: 가장 높은 score: 0.91796875로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_007_2_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_007_2_0_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_007_2_1_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_007_2_1_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_008_3.jpg
# bbox 1: 가장 높은 score: 0.83203125로 저장됨
# bbox 2: 가장 높은 score: 0.984375로 저장됨
# bbox 3: 가장 높은 score: 0.98046875로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_008_3_1_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_008_3_1_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_008_3_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_008_3_0_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_008_3_1_01.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_008_3_1_01.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_009_1.jpg
# bbox 1: 가장 높은 score: 0.97265625로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_009_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_009_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_010_1.jpg
# bbox 1: 가장 높은 score: 0.984375로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_010_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_010_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_011_1.jpg
# bbox 1: 가장 높은 score: 0.98046875로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_011_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_011_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_012_1.jpg
# bbox 1: 가장 높은 score: 0.984375로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_012_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_012_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_013_1.jpg
# bbox 1: 가장 높은 score: 0.96875로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_013_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_013_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_014_1.jpg
# bbox 1: 가장 높은 score: 0.98046875로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_014_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_014_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_015_1.jpg
# bbox 1: 가장 높은 score: 0.97265625로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_015_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_015_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_016_3.jpg
# bbox 1: 가장 높은 score: 0.93359375로 저장됨
# bbox 2: 가장 높은 score: 0.98046875로 저장됨
# bbox 3: 가장 높은 score: 0.98828125로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_016_3_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_016_3_0_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_016_3_1_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_016_3_1_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_016_3_1_01.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_016_3_1_01.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_017_3.jpg
# bbox 1: 가장 높은 score: 0.97265625로 저장됨
# bbox 2: 가장 높은 score: 0.98828125로 저장됨
# bbox 3: 가장 높은 score: 0.96875로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_017_3_1_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_017_3_1_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_017_3_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_017_3_0_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_017_3_1_01.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_017_3_1_01.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_018_4.jpg
# bbox 1: 가장 높은 score: 0.98828125로 저장됨
# bbox 2: 가장 높은 score: 0.98828125로 저장됨
# bbox 3: 가장 높은 score: 0.96875로 저장됨
# bbox 4: 가장 높은 score: 0.98828125로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_018_4_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_018_4_0_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_018_4_1_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_018_4_1_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_018_4_1_01.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_018_4_1_01.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_018_4_1_02.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_018_4_1_02.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_019_1.jpg
# bbox 1: 가장 높은 score: 0.984375로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_019_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_019_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_020_4.jpg
# bbox 1: 가장 높은 score: 0.98046875로 저장됨
# bbox 2: 가장 높은 score: 0.9296875로 저장됨
# bbox 3: 가장 높은 score: 0.9765625로 저장됨
# bbox 4: 가장 높은 score: 0.94921875로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_020_4_1_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_020_4_1_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_020_4_1_01.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_020_4_1_01.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_020_4_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_020_4_0_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_020_4_1_02.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_020_4_1_02.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_021_1.jpg
# bbox 1: 가장 높은 score: 0.984375로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_021_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_021_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_022_1.jpg
# bbox 1: 가장 높은 score: 0.98046875로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_022_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_022_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_023_1.jpg
# bbox 1: 가장 높은 score: 0.98828125로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_023_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_023_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_024_4.jpg
# bbox 1: 가장 높은 score: 0.98828125로 저장됨
# bbox 2: 가장 높은 score: 0.9765625로 저장됨
# bbox 3: 가장 높은 score: 0.984375로 저장됨
# bbox 4: 가장 높은 score: 0.953125로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_024_4_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_024_4_0_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_024_4_1_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_024_4_1_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_024_4_1_01.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_024_4_1_01.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_024_4_1_02.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_024_4_1_02.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_025_1.jpg
# bbox 1: 가장 높은 score: 0.9375로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_025_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_025_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_026_1.jpg
# bbox 1: 가장 높은 score: 0.9765625로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_026_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_026_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_027_1.jpg
# bbox 1: 가장 높은 score: 0.9609375로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_027_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_027_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_028_1.jpg
# bbox 1: 가장 높은 score: 0.9609375로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_028_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_028_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_029_3.jpg
# bbox 1: 가장 높은 score: 0.9609375로 저장됨
# bbox 2: 가장 높은 score: 0.9921875로 저장됨
# bbox 3: 가장 높은 score: 0.98046875로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_029_3_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_029_3_0_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_029_3_1_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_029_3_1_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_029_3_1_01.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_029_3_1_01.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_030_1.jpg
# bbox 1: 가장 높은 score: 0.984375로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_030_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_030_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_031_1.jpg
# bbox 1: 가장 높은 score: 0.52734375로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_031_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_031_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_032_1.jpg
# bbox 1: 가장 높은 score: 0.97265625로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_032_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_032_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_033_1.jpg
# bbox 1: 가장 높은 score: 0.98046875로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_033_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_033_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_034_2.jpg
# bbox 1: 가장 높은 score: 0.94140625로 저장됨
# bbox 2: 가장 높은 score: 0.9609375로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_034_2_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_034_2_0_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_034_2_1_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_034_2_1_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_035_1.jpg
# bbox 1: 가장 높은 score: 0.97265625로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_035_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_035_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_036_1.jpg
# bbox 1: 가장 높은 score: 0.92578125로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_036_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_036_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_037_1.jpg
# bbox 1: 가장 높은 score: 0.9765625로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_037_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_037_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_038_3.jpg
# bbox 1: 가장 높은 score: 0.97265625로 저장됨
# bbox 2: 가장 높은 score: 0.96484375로 저장됨
# bbox 3: 가장 높은 score: 0.9921875로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_038_3_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_038_3_0_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_038_3_1_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_038_3_1_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_038_3_1_01.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_038_3_1_01.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_039_1.jpg
# bbox 1: 가장 높은 score: 0.9375로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_039_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_039_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_040_1.jpg
# bbox 1: 가장 높은 score: 0.984375로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_040_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_040_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_041_2.jpg
# bbox 1: 가장 높은 score: 0.98046875로 저장됨
# bbox 2: 가장 높은 score: 0.94140625로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_041_2_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_041_2_0_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_041_2_0_01.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_041_2_0_01.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_042_1.jpg
# bbox 1: 가장 높은 score: 0.9609375로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_042_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_042_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_043_1.jpg
# bbox 1: 가장 높은 score: 0.96875로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_043_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_043_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_044_1.jpg
# bbox 1: 가장 높은 score: 0.98046875로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_044_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_044_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_045_1.jpg
# bbox 1: 가장 높은 score: 0.984375로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_045_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_045_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_046_1.jpg
# bbox 1: 가장 높은 score: 0.8671875로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_046_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_046_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_047_1.jpg
# bbox 1: 가장 높은 score: 0.97265625로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_047_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_047_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_048_1.jpg
# bbox 1: 가장 높은 score: 0.98828125로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_048_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_048_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_049_1.jpg
# bbox 1: 가장 높은 score: 0.9765625로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_049_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_049_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_050_1.jpg
# bbox 1: 가장 높은 score: 0.94921875로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_050_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_050_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_051_4.jpg
# bbox 1: 가장 높은 score: 0.984375로 저장됨
# bbox 2: 가장 높은 score: 0.9921875로 저장됨
# bbox 3: 가장 높은 score: 0.96875로 저장됨
# bbox 4: 가장 높은 score: 0.9453125로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_051_4_1_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_051_4_1_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_051_4_1_01.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_051_4_1_01.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_051_4_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_051_4_0_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_051_4_1_02.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_051_4_1_02.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_052_1.jpg
# bbox 1: 가장 높은 score: 0.98046875로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_052_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_052_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_053_1.jpg
# bbox 1: 가장 높은 score: 0.94921875로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_053_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_053_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_054_2.jpg
# bbox 1: 가장 높은 score: 0.9765625로 저장됨
# bbox 2: 가장 높은 score: 0.98828125로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_054_2_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_054_2_0_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_054_2_1_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_054_2_1_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_055_1.jpg
# bbox 1: 가장 높은 score: 0.98046875로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_055_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_055_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_056_2.jpg
# bbox 1: 가장 높은 score: 0.98046875로 저장됨
# bbox 2: 가장 높은 score: 0.875로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_056_2_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_056_2_0_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_056_2_1_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_056_2_1_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_057_2.jpg
# bbox 1: 가장 높은 score: 0.97265625로 저장됨
# bbox 2: 가장 높은 score: 0.984375로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_057_2_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_057_2_0_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_057_2_1_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_057_2_1_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_058_2.jpg
# bbox 1: 가장 높은 score: 0.97265625로 저장됨
# bbox 2: 가장 높은 score: 0.95703125로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_058_2_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_058_2_0_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_058_2_1_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_058_2_1_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_059_1.jpg
# bbox 1: 가장 높은 score: 0.9765625로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_059_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_059_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_060_1.jpg
# bbox 1: 가장 높은 score: 0.984375로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_060_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_060_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_061_1.jpg
# bbox 1: 가장 높은 score: 0.9609375로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_061_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_061_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_062_1.jpg
# bbox 1: 가장 높은 score: 0.9765625로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_062_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_062_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_063_1.jpg
# bbox 1: 가장 높은 score: 0.98046875로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_063_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_063_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_064_1.jpg
# bbox 1: 가장 높은 score: 0.953125로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_064_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_064_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_065_1.jpg
# bbox 1: 가장 높은 score: 0.9765625로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_065_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_065_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_066_2.jpg
# bbox 1: 가장 높은 score: 0.98046875로 저장됨
# bbox 2: 가장 높은 score: 0.875로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_066_2_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_066_2_0_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_066_2_1_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_066_2_1_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_067_1.jpg
# bbox 1: 가장 높은 score: 0.84765625로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_067_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_067_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_068_1.jpg
# bbox 1: 가장 높은 score: 0.98828125로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_068_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_068_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_069_1.jpg
# bbox 1: 가장 높은 score: 0.984375로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_069_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_069_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_070_1.jpg
# bbox 1: 가장 높은 score: 0.98828125로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_070_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_070_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_071_3.jpg
# bbox 1: 가장 높은 score: 0.9765625로 저장됨
# bbox 2: 가장 높은 score: 0.97265625로 저장됨
# bbox 3: 가장 높은 score: 0.94921875로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_071_3_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_071_3_0_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_071_3_0_01.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_071_3_0_01.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_071_3_0_02.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_071_3_0_02.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_072_3.jpg
# bbox 1: 가장 높은 score: 0.984375로 저장됨
# bbox 2: 가장 높은 score: 0.86328125로 저장됨
# bbox 3: 가장 높은 score: 0.95703125로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_072_3_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_072_3_0_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_072_3_1_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_072_3_1_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_072_3_1_01.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_072_3_1_01.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_073_1.jpg
# bbox 1: 가장 높은 score: 0.98046875로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_073_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_073_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_074_1.jpg
# bbox 1: 가장 높은 score: 0.95703125로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_074_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_074_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_075_1.jpg
# bbox 1: 가장 높은 score: 0.96875로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_075_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_075_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_076_3.jpg
# bbox 1: 가장 높은 score: 0.953125로 저장됨
# bbox 2: 가장 높은 score: 0.9765625로 저장됨
# bbox 3: 가장 높은 score: 0.94921875로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_076_3_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_076_3_0_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_076_3_0_01.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_076_3_0_01.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_076_3_0_02.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_076_3_0_02.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_077_1.jpg
# bbox 1: 가장 높은 score: 0.984375로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_077_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_077_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_078_1.jpg
# bbox 1: 가장 높은 score: 0.98046875로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_078_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_078_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_079_1.jpg
# bbox 1: 가장 높은 score: 0.984375로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_079_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_079_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_080_1.jpg
# bbox 1: 가장 높은 score: 0.98046875로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_080_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_080_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_081_1.jpg
# bbox 1: 가장 높은 score: 0.98046875로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_081_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_081_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_082_1.jpg
# bbox 1: 가장 높은 score: 0.9765625로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_082_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_082_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_083_1.jpg
# bbox 1: 가장 높은 score: 0.96484375로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_083_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_083_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_084_4.jpg
# bbox 1: 가장 높은 score: 0.6953125로 저장됨
# bbox 2: 가장 높은 score: 0.9765625로 저장됨
# bbox 3: 가장 높은 score: 0.6875로 저장됨
# bbox 4: 가장 높은 score: 0.94921875로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_084_4_1_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_084_4_1_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_084_4_1_01.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_084_4_1_01.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_084_4_1_02.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_084_4_1_02.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_084_4_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_084_4_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_085_1.jpg
# bbox 1: 가장 높은 score: 0.984375로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_085_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_085_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_086_2.jpg
# bbox 1: 가장 높은 score: 0.98046875로 저장됨
# bbox 2: 가장 높은 score: 0.9921875로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_086_2_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_086_2_0_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_086_2_1_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_086_2_1_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_087_1.jpg
# bbox 1: 가장 높은 score: 0.98046875로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_087_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_087_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_088_2.jpg
# bbox 1: 가장 높은 score: 0.984375로 저장됨
# bbox 2: 가장 높은 score: 0.97265625로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_088_2_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_088_2_0_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_088_2_1_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_088_2_1_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_089_3.jpg
# bbox 1: 가장 높은 score: 0.984375로 저장됨
# bbox 2: 가장 높은 score: 0.87890625로 저장됨
# bbox 3: 가장 높은 score: 0.984375로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_089_3_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_089_3_0_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_089_3_1_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_089_3_1_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_089_3_1_01.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_089_3_1_01.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_090_1.jpg
# bbox 1: 가장 높은 score: 0.98046875로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_090_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_090_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_091_2.jpg
# bbox 1: 가장 높은 score: 0.9765625로 저장됨
# bbox 2: 가장 높은 score: 0.98828125로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_091_2_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_091_2_0_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_091_2_1_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_091_2_1_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_092_2.jpg
# bbox 1: score 0.1025390625로 저장되지 않음
# bbox 2: score 0.15234375로 저장되지 않음
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_093_1.jpg
# bbox 1: 가장 높은 score: 0.97265625로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_093_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_093_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_094_3.jpg
# bbox 1: 가장 높은 score: 0.97265625로 저장됨
# bbox 2: 가장 높은 score: 0.984375로 저장됨
# bbox 3: 가장 높은 score: 0.9609375로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_094_3_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_094_3_0_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_094_3_1_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_094_3_1_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_094_3_1_01.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_094_3_1_01.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_095_3.jpg
# bbox 1: 가장 높은 score: 0.94140625로 저장됨
# bbox 2: 가장 높은 score: 0.89453125로 저장됨
# bbox 3: 가장 높은 score: 0.984375로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_095_3_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_095_3_0_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_095_3_1_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_095_3_1_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_095_3_1_01.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_095_3_1_01.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_096_1.jpg
# bbox 1: 가장 높은 score: 0.97265625로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_096_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_096_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_097_1.jpg
# bbox 1: 가장 높은 score: 0.98046875로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_097_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_097_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_098_3.jpg
# bbox 1: 가장 높은 score: 0.984375로 저장됨
# bbox 2: 가장 높은 score: 0.9375로 저장됨
# bbox 3: 가장 높은 score: 0.98046875로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_098_3_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_098_3_0_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_098_3_1_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_098_3_1_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_098_3_1_01.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_098_3_1_01.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_099_1.jpg
# bbox 1: 가장 높은 score: 0.9765625로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_099_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_099_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_100_2.jpg
# bbox 1: 가장 높은 score: 0.91015625로 저장됨
# bbox 2: 가장 높은 score: 0.984375로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_100_2_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_100_2_0_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_100_2_1_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_100_2_1_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_101_2.jpg
# bbox 1: 가장 높은 score: 0.65234375로 저장됨
# bbox 2: 가장 높은 score: 0.96484375로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_101_2_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_101_2_0_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_101_2_1_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_101_2_1_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_102_2.jpg
# bbox 1: 가장 높은 score: 0.98046875로 저장됨
# bbox 2: 가장 높은 score: 0.98828125로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_102_2_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_102_2_0_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_102_2_1_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_102_2_1_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_103_1.jpg
# bbox 1: 가장 높은 score: 0.96484375로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_103_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_103_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_104_1.jpg
# bbox 1: 가장 높은 score: 0.98046875로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_104_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_104_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_105_4.jpg
# bbox 1: 가장 높은 score: 0.98046875로 저장됨
# bbox 2: 가장 높은 score: 0.9296875로 저장됨
# bbox 3: 가장 높은 score: 0.9765625로 저장됨
# bbox 4: 가장 높은 score: 0.94921875로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_105_4_1_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_105_4_1_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_105_4_1_01.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_105_4_1_01.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_105_4_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_105_4_0_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_105_4_1_02.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_105_4_1_02.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_106_1.jpg
# bbox 1: 가장 높은 score: 0.98828125로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_106_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_106_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_107_1.jpg
# bbox 1: 가장 높은 score: 0.984375로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_107_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_107_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_108_1.jpg
# bbox 1: 가장 높은 score: 0.98046875로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_108_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_108_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_109_1.jpg
# bbox 1: score 0.06005859375로 저장되지 않음
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_110_1.jpg
# bbox 1: 가장 높은 score: 0.98046875로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_110_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_110_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_111_2.jpg
# bbox 1: 가장 높은 score: 0.98046875로 저장됨
# bbox 2: 가장 높은 score: 0.94140625로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_111_2_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_111_2_0_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_111_2_1_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_111_2_1_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_112_2.jpg
# bbox 1: 가장 높은 score: 0.9140625로 저장됨
# bbox 2: 가장 높은 score: 0.984375로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_112_2_1_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_112_2_1_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_112_2_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_112_2_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_113_1.jpg
# bbox 1: 가장 높은 score: 0.9765625로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_113_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_113_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_114_1.jpg
# bbox 1: 가장 높은 score: 0.9375로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_114_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_114_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_115_2.jpg
# bbox 1: 가장 높은 score: 0.97265625로 저장됨
# bbox 2: 가장 높은 score: 0.93359375로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_115_2_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_115_2_0_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_115_2_1_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_115_2_1_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_116_1.jpg
# bbox 1: 가장 높은 score: 0.96484375로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_116_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_116_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_117_3.jpg
# bbox 1: 가장 높은 score: 0.9140625로 저장됨
# bbox 2: 가장 높은 score: 0.9765625로 저장됨
# bbox 3: 가장 높은 score: 0.98828125로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_117_3_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_117_3_0_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_117_3_1_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_117_3_1_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_117_3_1_01.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_117_3_1_01.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_118_1.jpg
# bbox 1: 가장 높은 score: 0.98828125로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_118_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_118_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_119_1.jpg
# bbox 1: 가장 높은 score: 0.984375로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_119_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_119_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_120_1.jpg
# bbox 1: 가장 높은 score: 0.96484375로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_120_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_120_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_121_1.jpg
# bbox 1: 가장 높은 score: 0.95703125로 저장됨
# ...
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_214_1.jpg
# bbox 1: 가장 높은 score: 0.84765625로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_214_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_214_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_215_1.jpg
# bbox 1: 가장 높은 score: 0.921875로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_215_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_215_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_216_1.jpg
# bbox 1: 가장 높은 score: 0.984375로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_216_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_216_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_217_1.jpg
# bbox 1: 가장 높은 score: 0.984375로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_217_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_217_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_218_1.jpg
# bbox 1: 가장 높은 score: 0.984375로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_218_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_218_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_219_2.jpg
# bbox 1: 가장 높은 score: 0.7265625로 저장됨
# bbox 2: 가장 높은 score: 0.98046875로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_219_2_1_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_219_2_1_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_219_2_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_219_2_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_220_1.jpg
# bbox 1: 가장 높은 score: 0.97265625로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_220_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_220_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_221_3.jpg
# bbox 1: 가장 높은 score: 0.9765625로 저장됨
# bbox 2: 가장 높은 score: 0.734375로 저장됨
# bbox 3: 가장 높은 score: 0.80078125로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_221_3_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_221_3_0_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_221_3_1_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_221_3_1_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_221_3_1_01.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_221_3_1_01.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_222_1.jpg
# bbox 1: 가장 높은 score: 0.98046875로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_222_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_222_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_223_2.jpg
# bbox 1: 가장 높은 score: 0.98046875로 저장됨
# bbox 2: 가장 높은 score: 0.984375로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_223_2_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_223_2_0_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_223_2_1_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_223_2_1_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_224_1.jpg
# bbox 1: 가장 높은 score: 0.98046875로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_224_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_224_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_225_1.jpg
# bbox 1: 가장 높은 score: 0.94140625로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_225_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_225_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_226_2.jpg
# bbox 1: 가장 높은 score: 0.96875로 저장됨
# bbox 2: 가장 높은 score: 0.98046875로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_226_2_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_226_2_0_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_226_2_0_01.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_226_2_0_01.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_227_1.jpg
# bbox 1: 가장 높은 score: 0.98828125로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_227_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_227_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_228_1.jpg
# bbox 1: 가장 높은 score: 0.9765625로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_228_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_228_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_229_1.jpg
# bbox 1: 가장 높은 score: 0.984375로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_229_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_229_1_0_00.txt
# 레이블이 없는 이미지: V003_3_3_1_2_4_2_2_1_0_0_20221019_5119_20240422195048.jpg
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_230_1.jpg
# bbox 1: 가장 높은 score: 0.875로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_230_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_230_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_231_3.jpg
# bbox 1: 가장 높은 score: 0.98046875로 저장됨
# bbox 2: 가장 높은 score: 0.66015625로 저장됨
# bbox 3: 가장 높은 score: 0.96484375로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_231_3_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_231_3_0_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_231_3_1_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_231_3_1_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_231_3_1_01.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_231_3_1_01.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_232_1.jpg
# bbox 1: 가장 높은 score: 0.98828125로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_232_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_232_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_233_2.jpg
# bbox 1: 가장 높은 score: 0.984375로 저장됨
# bbox 2: 가장 높은 score: 0.8515625로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_233_2_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_233_2_0_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_233_2_1_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_233_2_1_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_234_1.jpg
# bbox 1: 가장 높은 score: 0.984375로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_234_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_234_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_235_1.jpg
# bbox 1: 가장 높은 score: 0.97265625로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_235_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_235_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_236_1.jpg
# bbox 1: 가장 높은 score: 0.98828125로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_236_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_236_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_237_1.jpg
# bbox 1: 가장 높은 score: 0.98828125로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_237_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_237_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_238_3.jpg
# bbox 1: 가장 높은 score: 0.97265625로 저장됨
# bbox 2: 가장 높은 score: 0.984375로 저장됨
# bbox 3: 가장 높은 score: 0.98046875로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_238_3_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_238_3_0_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_238_3_1_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_238_3_1_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_238_3_1_01.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_238_3_1_01.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_239_3.jpg
# bbox 1: 가장 높은 score: 0.98828125로 저장됨
# bbox 2: 가장 높은 score: 0.96875로 저장됨
# bbox 3: 가장 높은 score: 0.83984375로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_239_3_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_239_3_0_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_239_3_1_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_239_3_1_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_239_3_1_01.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_239_3_1_01.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_240_3.jpg
# bbox 1: 가장 높은 score: 0.98828125로 저장됨
# bbox 2: 가장 높은 score: 0.96484375로 저장됨
# bbox 3: 가장 높은 score: 0.9921875로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_240_3_1_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_240_3_1_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_240_3_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_240_3_0_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_240_3_1_01.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_240_3_1_01.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_241_3.jpg
# bbox 1: 가장 높은 score: 0.984375로 저장됨
# bbox 2: 가장 높은 score: 0.95703125로 저장됨
# bbox 3: 가장 높은 score: 0.984375로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_241_3_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_241_3_0_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_241_3_1_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_241_3_1_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_241_3_1_01.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_241_3_1_01.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_242_2.jpg
# bbox 1: 가장 높은 score: 0.98046875로 저장됨
# bbox 2: 가장 높은 score: 0.90625로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_242_2_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_242_2_0_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_242_2_1_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_242_2_1_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_243_2.jpg
# bbox 1: 가장 높은 score: 0.9609375로 저장됨
# bbox 2: 가장 높은 score: 0.95703125로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_243_2_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_243_2_0_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_243_2_1_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_243_2_1_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_244_1.jpg
# bbox 1: 가장 높은 score: 0.98046875로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_244_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_244_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_245_3.jpg
# bbox 1: 가장 높은 score: 0.984375로 저장됨
# bbox 2: 가장 높은 score: 0.9765625로 저장됨
# bbox 3: 가장 높은 score: 0.97265625로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_245_3_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_245_3_0_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_245_3_1_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_245_3_1_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_245_3_1_01.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_245_3_1_01.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_246_1.jpg
# bbox 1: 가장 높은 score: 0.92578125로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_246_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_246_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_247_2.jpg
# bbox 1: 가장 높은 score: 0.98828125로 저장됨
# bbox 2: 가장 높은 score: 0.97265625로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_247_2_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_247_2_0_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_247_2_1_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_247_2_1_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_248_1.jpg
# bbox 1: 가장 높은 score: 0.734375로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_248_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_248_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_249_1.jpg
# bbox 1: 가장 높은 score: 0.97265625로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_249_1_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_249_1_0_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_250_2.jpg
# bbox 1: 가장 높은 score: 0.984375로 저장됨
# bbox 2: 가장 높은 score: 0.73828125로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_250_2_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_250_2_0_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_250_2_1_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_250_2_1_00.txt
# 이미지 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/images/oi_251_2.jpg
# bbox 1: 가장 높은 score: 0.984375로 저장됨
# bbox 2: 가장 높은 score: 0.984375로 저장됨
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_251_2_0_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_251_2_0_00.txt
# 마스크 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_251_2_1_00.png
# 바운딩 박스 저장됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_251_2_1_00.txt

# %% [markdown]
# #### post processing

# %%
import os
import cv2
import numpy as np


# 마스크 폴더 경로
mask_dir = '/home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks'
label_dir = '/home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels'  # 바운딩 박스 정보가 저장된 폴더

# 마스크 및 바운딩 박스 파일 정리 함수
def clean_masks_and_bboxes_by_size(mask_list, area_threshold=0.30):
    total_deleted = 0  # 삭제된 마스크 개수 저장 변수
    # 마스크 파일들을 처리
    for mask_file in mask_list:
        # 마스크 파일 로드 (이진 마스크: 0과 255로만 구성)
        mask = cv2.imread(mask_file, cv2.IMREAD_GRAYSCALE)
        if mask is None:
            print(f"마스크 파일을 불러오지 못함: {mask_file}")
            continue
        
        # 활성화된 마스크 픽셀 수 계산 (255로 된 픽셀만)
        mask_area = np.sum(mask == 255)
        
        # 마스크 이미지의 전체 픽셀 수
        total_pixels = mask.shape[0] * mask.shape[1]
        
        # 마스크가 이미지의 몇 %를 차지하는지 계산
        mask_area_ratio = mask_area / total_pixels
        
        # 마스크 파일명에서 확장자를 제거하고 바운딩 박스 파일명 생성
        base_name = os.path.splitext(os.path.basename(mask_file))[0]
        label_file = os.path.join(label_dir, f"{base_name}.txt")
        
        # 조건에 맞지 않는 마스크 파일 및 해당하는 바운딩 박스 파일 삭제
        if mask_area_ratio > area_threshold:
            os.remove(mask_file)
            if os.path.exists(label_file):
                os.remove(label_file)  # 바운딩 박스 파일도 삭제
                print(f"삭제됨: {label_file} (바운딩 박스)")
            total_deleted += 1  # 삭제된 마스크 개수 증가
            print(f"삭제됨: {mask_file} (차지 비율: {mask_area_ratio:.2f})")
        # else:
        #     print(f"유지됨: {mask_file} (차지 비율: {mask_area_ratio:.2f})")

    print(f"총 삭제된 마스크 및 바운딩 박스 개수: {total_deleted}")

# 마스크 경로 목록 생성
mask_paths = []
for mask_file in os.listdir(mask_dir):
    if mask_file.endswith(('.jpg', '.jpeg', '.png')):  # 이미지 파일만 처리
        mask_path = os.path.join(mask_dir, mask_file)
        mask_paths.append(mask_path)

# 마스크 파일 크기 조건 (전체 이미지의 30% 이하만 유지)
area_threshold = 0.3

# 마스크 및 바운딩 박스 정리 실행
clean_masks_and_bboxes_by_size(mask_paths, area_threshold=area_threshold)
# Out:
# 삭제됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_210_2_1_00.txt (바운딩 박스)
# 삭제됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_210_2_1_00.png (차지 비율: 0.70)
# 삭제됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_138_2_1_00.txt (바운딩 박스)
# 삭제됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_138_2_1_00.png (차지 비율: 0.53)
# 삭제됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_008_3_1_00.txt (바운딩 박스)
# 삭제됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_008_3_1_00.png (차지 비율: 0.34)
# 삭제됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_112_2_1_00.txt (바운딩 박스)
# 삭제됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_112_2_1_00.png (차지 비율: 0.33)
# 삭제됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_188_3_1_00.txt (바운딩 박스)
# 삭제됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_188_3_1_00.png (차지 비율: 0.42)
# 삭제됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_242_2_1_00.txt (바운딩 박스)
# 삭제됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_242_2_1_00.png (차지 비율: 0.63)
# 삭제됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_124_2_1_00.txt (바운딩 박스)
# 삭제됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_124_2_1_00.png (차지 비율: 0.32)
# 삭제됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_181_3_1_01.txt (바운딩 박스)
# 삭제됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_181_3_1_01.png (차지 비율: 0.43)
# 삭제됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_007_2_1_00.txt (바운딩 박스)
# 삭제됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_007_2_1_00.png (차지 비율: 0.48)
# 삭제됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/labels/oi_134_3_1_00.txt (바운딩 박스)
# 삭제됨: /home/knuvi/Desktop/song/cucumber-image/data/oi_seg/masks/oi_134_3_1_00.png (차지 비율: 0.40)
# 총 삭제된 마스크 및 바운딩 박스 개수: 10
